# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from joblib import dump

from src.config import DADOS_LIMPOS, MODELO_FINAL
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_households  population_per_househoulds  \
# 0                  5              6.984127                    2.555556
# 1                  5              6.238137                    2.109842
# 2                  2              4.294117                    2.026891
# 3                  2              4.242424                    2.640152
# 4                  2              5.343676                    2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   longitude                   17564 non-null  float32
#  1   latitude                    17564 non-null  float32
#  2   housing_median_age          17564 non-null  int8
#  3   total_rooms                 17564 non-null  int16
#  4   total_bedrooms              17564 non-null  int16
#  5   population                  17564 non-null  int16
#  6   households                  17564 non-null  int16
#  7   median_income               17564 non-null  float32
#  8   median_house_value          17564 non-null  int32
#  9   ocean_proximity             17564 non-null  category
#  10  median_income_cat           17564 non-null  int64
#  11  rooms_per_households        17564 non-null  float32
#  12  population_per_househoulds  17564 non-null  float32
#  13  bedrooms_per_room           17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population',
#        'population_per_househoulds', 'rooms_per_households', 'total_bedrooms',
#        'total_rooms'],
#       dtype='object')

# %%
pipeline_robust = Pipeline(steps=[
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])

preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler),
    ],
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_households  population_per_househoulds  bedrooms_per_room
# 0              6.984127                    2.555556           0.146591
# 1              6.238137                    2.109842           0.155797
# 2              4.294117                    2.026891           0.260274
# 3              4.242424                    2.640152           0.252679
# 4              5.343676                    2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree": [1, 2, 3],
    "regressor__reg__alpha": [1E-2, 5E-2, 0.1, 0.25, 0.5, 1.0, 2.0, 5.0, 10.0, 20.0, 50.0],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=Ridge(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution="normal"),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0, 2.0, 5.0, 10.0, 20.0,
#                                                    50.0]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 33 candidates, totalling 165 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0, 2.0, 5.0, 10.0, 20.0,
#                                                    50.0]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 10.0}

# %%
grid_search.best_score_
# Out:
# -50450.66227362168

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                                     coeficiente
# robust_scaler_poly__longitude                         -1.023268
# robust_scaler_poly__latitude                          -0.957370
# one_hot__ocean_proximity_INLAND                       -0.460141
# robust_scaler_poly__latitude longitude populati...    -0.418530
# robust_scaler_poly__population_per_househoulds        -0.332581
# ...                                                         ...
# robust_scaler_poly__latitude^2 longitude               0.247169
# robust_scaler_poly__housing_median_age median_i...     0.249335
# robust_scaler_poly__latitude median_income popu...     0.253952
# robust_scaler_poly__bedrooms_per_room                  0.337635
# robust_scaler_poly__median_income                      0.978976
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs)

# %%
coefs[coefs["coeficiente"] == 0]
# Out:
# Empty DataFrame
# Columns: [coeficiente]
# Index: []

# %%
coefs[coefs["coeficiente"].between(-0.2, 0.2) & (coefs["coeficiente"] != 0)]
# Out:
#                                                     coeficiente
# one_hot__ocean_proximity_NEAR BAY                     -0.197772
# robust_scaler_poly__housing_median_age populati...    -0.197256
# robust_scaler_poly__longitude median_income           -0.189891
# robust_scaler_poly__households median_income^2        -0.182289
# robust_scaler_poly__housing_median_age median_i...    -0.181782
# ...                                                         ...
# robust_scaler_poly__total_bedrooms                     0.169354
# robust_scaler_poly__bedrooms_per_room rooms_per...     0.172941
# robust_scaler_poly__median_income population po...     0.176900
# robust_scaler_poly__median_income population ro...     0.177706
# robust_scaler_poly__bedrooms_per_room median_in...     0.188088
#
# [341 rows x 1 columns]

# %%
plot_coeficientes(coefs[~coefs["coeficiente"].between(-0.2, 0.2)])

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": QuantileTransformer(output_distribution="normal"),
    },
    "Ridge_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.006559   0.007373 -0.000081
# 1            DummyRegressor  0.004001   0.006553 -0.000146
# 2            DummyRegressor  0.004987    0.00505 -0.001737
# 3            DummyRegressor  0.003013   0.006511 -0.000101
# 4            DummyRegressor   0.00451   0.006233 -0.000114
# 5          LinearRegression  0.080611   0.013997  0.682162
# 6          LinearRegression  0.046712   0.015198   0.66999
# 7          LinearRegression  0.049983   0.016518  0.649247
# 8          LinearRegression  0.043463   0.013928  0.669873
# 9          LinearRegression   0.04792   0.015904  0.669023
# 10  LinearRegression_target  0.067864   0.018351  0.691862
# 11  LinearRegression_target  0.073747   0.018147  0.678499
# 12  LinearRegression_target  0.061558   0.017554  0.653819
# 13  LinearRegression_target  0.065444   0.017633    0.6839
# 14  LinearRegression_target  0.065431    0.01551  0.682649
# 15        Ridge_grid_search  0.285578   0.030194  0.744253
# 16        Ridge_grid_search  0.242356   0.035951  0.723722
# 17        Ridge_grid_search  0.231948   0.028054  0.697863
# 18        Ridge_grid_search  0.212572   0.029322  0.725346
# 19        Ridge_grid_search  0.313466   0.036879  0.725333
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.013932
# 1                 -75787.787194                    -95217.629397     0.010554
# 2                 -76753.598961                    -96253.253947     0.010037
# 3                 -76837.804811                    -95983.885799     0.009524
# 4                 -76617.245449                    -96182.764729     0.010744
# 5                 -39855.690996                    -54254.958188     0.094607
# 6                 -40272.565467                    -54695.230283     0.061909
# 7                  -42178.05929                    -56955.988706     0.066501
# 8                 -40806.492497                    -55146.318803     0.057391
# 9                 -40788.496497                     -55331.35106     0.063824
# 10                -37800.687667                    -53420.643518     0.086215
# 11                -38293.132847                    -53985.463082     0.091893
# 12                -40282.777182                    -56583.523838     0.079111
# 13                -38591.124219                    -53962.040898     0.083077
# 14                -38409.369105                    -54180.446055      0.08094
# 15                -34110.414088                    -48667.846584     0.315771
# 16                -35040.344055                    -50044.836904     0.278307
# 17                -37078.755985                    -52861.594411     0.260002
# 18                -35238.084044                      -50300.1567     0.241895
# 19                -35269.039976                    -50405.231107     0.350345

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.004614   0.006344 -0.000436
# LinearRegression         0.053738   0.015109  0.668059
# LinearRegression_target  0.066809   0.017439  0.678146
# Ridge_grid_search        0.257184    0.03208  0.723303
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                -38675.418204
# Ridge_grid_search                       -35347.32763
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.010958
# LinearRegression                           -55276.769408     0.068847
# LinearRegression_target                    -54426.423478     0.084248
# Ridge_grid_search                          -50455.933141     0.289264

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.004614   0.006344 -0.000436
# LinearRegression         0.053738   0.015109  0.668059
# LinearRegression_target  0.066809   0.017439  0.678146
# Ridge_grid_search        0.257184    0.03208  0.723303
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                -38675.418204
# Ridge_grid_search                       -35347.32763
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.010958
# LinearRegression                           -55276.769408     0.068847
# LinearRegression_target                    -54426.423478     0.084248
# Ridge_grid_search                          -50455.933141     0.289264

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)

# %% [markdown]
# https://scikit-learn.org/stable/model_persistence.html

# %%
dump(grid_search.best_estimator_, MODELO_FINAL)
# Out:
# ['C:\\Users\\rafae\\OneDrive\\Cursos\\Hashtag\\Ciencias de dados\\projetos\\05-projeto\\modelos\\ridge_polyfeat_target_quantile.joblib']
