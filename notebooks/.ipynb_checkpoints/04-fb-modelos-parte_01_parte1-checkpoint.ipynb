# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_households  population_per_househoulds  \
# 0                  5              6.984127                    2.555556
# 1                  5              6.238137                    2.109842
# 2                  2              4.294117                    2.026891
# 3                  2              4.242424                    2.640152
# 4                  2              5.343676                    2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   longitude                   17564 non-null  float32
#  1   latitude                    17564 non-null  float32
#  2   housing_median_age          17564 non-null  int8
#  3   total_rooms                 17564 non-null  int16
#  4   total_bedrooms              17564 non-null  int16
#  5   population                  17564 non-null  int16
#  6   households                  17564 non-null  int16
#  7   median_income               17564 non-null  float32
#  8   median_house_value          17564 non-null  int32
#  9   ocean_proximity             17564 non-null  category
#  10  median_income_cat           17564 non-null  int64
#  11  rooms_per_households        17564 non-null  float32
#  12  population_per_househoulds  17564 non-null  float32
#  13  bedrooms_per_room           17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
#Target
coluna_target = ['median_house_value'] 

#categorias que não tem ordem
coluna_one_hot_encoder = ['ocean_proximity']

#categorias que tem ordem
coluna_ordinal_encoder = ['median_income_cat']

# %%
#colunas robust scaler
colunas_robust_scaler = df.columns.difference(coluna_one_hot_encoder + coluna_ordinal_encoder + coluna_target)

#colunas standard scaler
colunas_standard_scaler = ['longitude', 'latitude', 'housing_median_age'] #Colunas que tem distribuição parecida bimodal

#colunas power transform
colunas_power_scaler = df.columns.difference(coluna_one_hot_encoder + coluna_ordinal_encoder + coluna_target + colunas_standard_scaler)

# %%
#criando meu preprocessamento de colunas


#Aplico apenas o preprocessamento das colunas categóricas
preprocessamento_categoricas = ColumnTransformer(
    transformers=[
        ('ordinal_encoder', OrdinalEncoder(categories='auto'), coluna_ordinal_encoder), #O auto auto reconhece as categorias
        ('one_hot_encoder', OneHotEncoder(drop='first'), coluna_one_hot_encoder)
    ],
    remainder='passthrough' #Não faça nada com as demais colunas
)

#Aplicando o robust scaler a todas as colunas numericas
preprocessamento_simples = ColumnTransformer(
    transformers=[
        ('ordinal_encoder', OrdinalEncoder(categories='auto'), coluna_ordinal_encoder), #O auto auto reconhece as categorias
        ('one_hot_encoder', OneHotEncoder(drop='first'), coluna_one_hot_encoder),
        ('robust_scaler', RobustScaler(), colunas_robust_scaler) #Parecido com o standard, mas menos sensivel a outliers(bom de usar quando minha base tem muitos outliers)
    ],
)


#Aplico o standard scaler nas bimodais e o power transform nas demais + preprocessamento de categóricas
preprocessamento_completo = ColumnTransformer(
    transformers=[
        ('ordinal_encoder', OrdinalEncoder(categories='auto'), coluna_ordinal_encoder), #O auto auto reconhece as categorias
        ('one_hot_encoder', OneHotEncoder(drop='first'), coluna_one_hot_encoder),
        ('standard_scaler', StandardScaler(), colunas_standard_scaler),
        ('power_transform', PowerTransformer(), colunas_power_scaler)
    ],
)

# %%
#Separando meu target das features

#Features
X = df.drop(columns=coluna_target)

#Target
y = df[coluna_target]

# %%
#Verificando se meu modelo fica melhor sem transformação de target, com power ou
#quantile

param_grid = {
    'regressor__preprocessor': [preprocessamento_simples, preprocessamento_categoricas, preprocessamento_completo],
    'transformer' : [None, PowerTransformer(), QuantileTransformer(output_distribution='normal')]
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    preprocessor=preprocessamento_completo,
    target_transformer=PowerTransformer(),
    param_grid = param_grid   
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('standard_scaler',
#                                                                                                               StandardScaler(),
#                                                                                                               ['longitude',...
#                                                                                       Index(['bedrooms_per_room', 'households', 'median_income', 'population',
#        'population_per_househoulds', 'rooms_per_households', 'total_bedrooms',
#        'total_rooms'],
#       dtype='object'))])],
#                          'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('standard_scaler',
#                                                                                                               StandardScaler(),
#                                                                                                               ['longitude',...
#                                                                                       Index(['bedrooms_per_room', 'households', 'median_income', 'population',
#        'population_per_househoulds', 'rooms_per_households', 'total_bedrooms',
#        'total_rooms'],
#       dtype='object'))])],
#                          'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor': ColumnTransformer(transformers=[('ordinal_encoder', OrdinalEncoder(),
#                                   ['median_income_cat']),
#                                  ('one_hot_encoder', OneHotEncoder(drop='first'),
#                                   ['ocean_proximity']),
#                                  ('robust_scaler', RobustScaler(),
#                                   Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#         'longitude', 'median_income', 'population',
#         'population_per_househoulds', 'rooms_per_households', 'total_bedrooms',
#         'total_rooms'],
#        dtype='object'))]),
#  'transformer': QuantileTransformer(output_distribution='normal')}

# %%
grid_search.best_estimator_
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                       ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                        OrdinalEncoder(),
#                                                                                        ['median_income_cat']),
#                                                                                       ('one_hot_encoder',
#                                                                                        OneHotEncoder(drop='first'),
#                                                                                        ['ocean_proximity']),
#                                                                                       ('robust_scaler',
#                                                                                        RobustScaler(),
#                                                                                        Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population',
#        'population_per_househoulds', 'rooms_per_households', 'total_bedrooms',
#        'total_rooms'],
#       dtype='object'))])),
#                                                      ('reg',
#                                                       LinearRegression())]),
#                            transformer=QuantileTransformer(output_distribution='normal'))

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_['reg'].coef_,
    grid_search.best_estimator_.regressor_['preprocessor'].get_feature_names_out(),
)

coefs
# Out:
#                                              coeficiente
# robust_scaler__latitude                        -1.079293
# robust_scaler__longitude                       -1.067477
# one_hot_encoder__ocean_proximity_INLAND        -0.451504
# robust_scaler__population_per_househoulds      -0.235216
# one_hot_encoder__ocean_proximity_NEAR BAY      -0.204361
# robust_scaler__total_rooms                     -0.099872
# robust_scaler__total_bedrooms                  -0.079380
# one_hot_encoder__ocean_proximity_NEAR OCEAN    -0.057423
# robust_scaler__population                      -0.034105
# ordinal_encoder__median_income_cat              0.033548
# robust_scaler__housing_median_age               0.121104
# robust_scaler__rooms_per_households             0.179230
# robust_scaler__bedrooms_per_room                0.244768
# robust_scaler__households                       0.275063
# robust_scaler__median_income                    0.805473

# %%
plot_coeficientes(coefs)

# %%
#Comparando os modelos já treinados com meu gridsearch

regressors = {
    #Dummyregressor
    'DummyRegressor' : {
        'preprocessor': None,
        'regressor': DummyRegressor(strategy='mean'),
        'target_transformer': None,
    },

    #LinearRegressor sem transformação de target e só com categórcas
     'LinearRegression' : {
        'preprocessor': preprocessamento_categoricas,
        'regressor': LinearRegression(),
        'target_transformer': None,
    },

    
    #LinearRegressor com transformação de target quantile transformer (best param do grid search)
     'LinearRegression_grid_seach' : {
        'preprocessor': grid_search.best_estimator_.regressor_['preprocessor'],
        'regressor': grid_search.best_estimator_.regressor_['reg'],
        'target_transformer': grid_search.best_estimator_.transformer_,
    },
}

resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                           model  fit_time score_time   test_r2  \
# 0                DummyRegressor   0.00353   0.001998 -0.000081
# 1                DummyRegressor  0.003016   0.002491 -0.000146
# 2                DummyRegressor  0.000993   0.004988 -0.001737
# 3                DummyRegressor  0.007524   0.006538 -0.000101
# 4                DummyRegressor  0.002002   0.008661 -0.000114
# 5              LinearRegression  0.020745   0.009348  0.682162
# 6              LinearRegression   0.01604   0.007113   0.66999
# 7              LinearRegression  0.022022   0.007571  0.649247
# 8              LinearRegression  0.017555   0.007001  0.669873
# 9              LinearRegression  0.012025   0.004999  0.669023
# 10  LinearRegression_grid_seach  0.022799   0.009001  0.691884
# 11  LinearRegression_grid_seach  0.031009   0.005917  0.678548
# 12  LinearRegression_grid_seach   0.02206   0.013266  0.654383
# 13  LinearRegression_grid_seach    0.0416   0.008822  0.683548
# 14  LinearRegression_grid_seach  0.024451   0.007005  0.682133
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.005528
# 1                 -75787.787194                    -95217.629397     0.005506
# 2                 -76753.598961                    -96253.253947      0.00598
# 3                 -76837.804811                    -95983.885799     0.014062
# 4                 -76617.245449                    -96182.764729     0.010663
# 5                 -39855.690921                    -54254.958115     0.030093
# 6                 -40272.565406                    -54695.230224     0.023153
# 7                 -42178.059246                    -56955.988686     0.029593
# 8                 -40806.492452                     -55146.31876     0.024556
# 9                 -40788.496555                    -55331.351171     0.017024
# 10                -37799.904188                     -53418.73859     0.031799
# 11                -38293.521304                    -53981.334105     0.036926
# 12                -40277.040467                    -56537.441091     0.035326
# 13                -38607.362792                    -53992.067912     0.050422
# 14                -38411.251093                    -54224.415921     0.031456

# %%
df_resultados.groupby('model').mean()
# Out:
#                              fit_time score_time   test_r2  \
# model
# DummyRegressor               0.003413   0.004935 -0.000436
# LinearRegression             0.017678   0.007206  0.668059
# LinearRegression_grid_seach  0.028384   0.008802  0.678099
#
#                             test_neg_mean_absolute_error  \
# model
# DummyRegressor                             -76702.495836
# LinearRegression                           -40780.260916
# LinearRegression_grid_seach                -38677.815969
#
#                             test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                 -95975.447913     0.008348
# LinearRegression                               -55276.769391     0.024884
# LinearRegression_grid_seach                    -54430.799524     0.037186

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, eng_formatter=True)
