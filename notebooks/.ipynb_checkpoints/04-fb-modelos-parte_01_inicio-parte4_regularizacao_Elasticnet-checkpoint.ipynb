# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_households  population_per_househoulds  \
# 0                  5              6.984127                    2.555556
# 1                  5              6.238137                    2.109842
# 2                  2              4.294117                    2.026891
# 3                  2              4.242424                    2.640152
# 4                  2              5.343676                    2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   longitude                   17564 non-null  float32
#  1   latitude                    17564 non-null  float32
#  2   housing_median_age          17564 non-null  int8
#  3   total_rooms                 17564 non-null  int16
#  4   total_bedrooms              17564 non-null  int16
#  5   population                  17564 non-null  int16
#  6   households                  17564 non-null  int16
#  7   median_income               17564 non-null  float32
#  8   median_house_value          17564 non-null  int32
#  9   ocean_proximity             17564 non-null  category
#  10  median_income_cat           17564 non-null  int64
#  11  rooms_per_households        17564 non-null  float32
#  12  population_per_househoulds  17564 non-null  float32
#  13  bedrooms_per_room           17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
#Target
coluna_target = ['median_house_value'] 

#categorias que não tem ordem
coluna_one_hot_encoder = ['ocean_proximity']

#categorias que tem ordem
coluna_ordinal_encoder = ['median_income_cat']

# %%
#colunas robust scaler
colunas_robust_scaler = df.columns.difference(coluna_one_hot_encoder + coluna_ordinal_encoder + coluna_target)

# %%
#criando meu preprocessamento de colunas e features polinomiais

#Criando um pipeline para minhas colunas numericas
pipeline_robust = Pipeline(steps=[
    ('robust_scaler', RobustScaler()), #Primeiro aplico o robust scaler
    ('poly', PolynomialFeatures(degree=1, include_bias=False)) #Em cima desse resultado aplico o Polynomial features
])

#Aplicando o resultado do pipeline anterior scaler a todas as colunas numericas e preprocessamento categórcas
preprocessamento = ColumnTransformer(
    transformers=[
        ('ordinal_encoder', OrdinalEncoder(categories='auto'), coluna_ordinal_encoder), #O auto auto reconhece as categorias
        ('one_hot_encoder', OneHotEncoder(drop='first'), coluna_one_hot_encoder),
        ('robust_scaler_poly', pipeline_robust, colunas_robust_scaler) #Parecido com o standard, mas menos sensivel a outliers(bom de usar quando minha base tem muitos outliers)
    ],
)

# %%
#Separando meu target das features

#Features
X = df.drop(columns=coluna_target)

#Target
y = df[coluna_target]

# %%
#Verificando se meu modelo fica melhor sem transformação de target, com power ou
#quantile

param_grid = {
    'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,2,3]
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution='normal'),
    param_grid = param_grid   
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_sc...
#        'population_per_househoulds', 'rooms_per_households', 'total_bedrooms',
#        'total_rooms'],
#       dtype='object'))])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_sc...
#        'population_per_househoulds', 'rooms_per_households', 'total_bedrooms',
#        'total_rooms'],
#       dtype='object'))])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3}

# %%
grid_search.best_estimator_
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                       ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                        OrdinalEncoder(),
#                                                                                        ['median_income_cat']),
#                                                                                       ('one_hot_encoder',
#                                                                                        OneHotEncoder(drop='first'),
#                                                                                        ['ocean_proximity']),
#                                                                                       ('robust_scaler_poly',
#                                                                                        Pipeline(steps=[('robust_scaler',
#                                                                                                         RobustScaler()),
#                                                                                                        ('poly',
#                                                                                                         PolynomialFeatures(degree=3,
#                                                                                                                            include_bias=False))]),
#                                                                                        Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population',
#        'population_per_househoulds', 'rooms_per_households', 'total_bedrooms',
#        'total_rooms'],
#       dtype='object'))])),
#                                                      ('reg',
#                                                       LinearRegression())]),
#                            transformer=QuantileTransformer(output_distribution='normal'))

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_['reg'].coef_,
    grid_search.best_estimator_.regressor_['preprocessor'].get_feature_names_out(),
)

coefs
# Out:
#                                                       coeficiente
# robust_scaler_poly__longitude total_rooms          -311039.686117
# robust_scaler_poly__housing_median_age total_rooms -230110.629989
# robust_scaler_poly__rooms_per_households total_... -214953.630983
# robust_scaler_poly__latitude total_rooms           -211272.575990
# robust_scaler_poly__latitude population_per_hou... -207488.137145
# ...                                                           ...
# robust_scaler_poly__longitude population            170621.573047
# robust_scaler_poly__households                      171431.346919
# robust_scaler_poly__latitude population rooms_p...  208835.835051
# robust_scaler_poly__bedrooms_per_room households    219780.022910
# robust_scaler_poly__latitude population             230767.920013
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs)

# %%
#Verificando se há algum coeficiente nulo

coefs[coefs['coeficiente'] == 0]
# Out:
# Empty DataFrame
# Columns: [coeficiente]
# Index: []

# %%
#Verificando coeficientes que estão dentro de faixas insignificantes

coefs[coefs['coeficiente'].between(-100000, 100000)]
# Out:
#                                                      coeficiente
# robust_scaler_poly__households housing_median_a... -93669.196975
# robust_scaler_poly__population_per_househoulds ... -85555.469816
# robust_scaler_poly__latitude population_per_hou... -83193.916707
# robust_scaler_poly__households^2 population_per... -64873.450625
# robust_scaler_poly__housing_median_age populati... -64837.816006
# ...                                                          ...
# robust_scaler_poly__housing_median_age total_be...  73065.150875
# robust_scaler_poly__bedrooms_per_room rooms_per...  75481.261112
# robust_scaler_poly__latitude rooms_per_households   78345.975690
# robust_scaler_poly__rooms_per_households^2          79961.441406
# robust_scaler_poly__households rooms_per_househ...  93228.663826
#
# [343 rows x 1 columns]

# %%
#Criando o gráfico dos coeficientes relevantes
plot_coeficientes(coefs[~coefs['coeficiente'].between(-100000, 100000)])

# %%
#Comparando os modelos já treinados com meu gridsearch

regressors = {
    #Dummyregressor
    'DummyRegressor' : {
        'preprocessor': None,
        'regressor': DummyRegressor(strategy='mean'),
        'target_transformer': None,
    },

    #LinearRegressor sem transformação de target e só com categórcas
     'LinearRegression' : {
        'preprocessor': preprocessamento,
        'regressor': LinearRegression(),
        'target_transformer': None,
    },

    
    #LinearRegressor com transformação de target quantile transformer (best param do grid search)
     'LinearRegression_grid_seach' : {
        'preprocessor': grid_search.best_estimator_.regressor_['preprocessor'],
        'regressor': grid_search.best_estimator_.regressor_['reg'],
        'target_transformer': grid_search.best_estimator_.transformer_,
    },
}

resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                           model  fit_time score_time   test_r2  \
# 0                DummyRegressor   0.00354   0.003002 -0.000081
# 1                DummyRegressor  0.002034   0.008515 -0.000146
# 2                DummyRegressor  0.019569   0.005554 -0.001737
# 3                DummyRegressor  0.004037   0.003557 -0.000101
# 4                DummyRegressor  0.003001   0.004998 -0.000114
# 5              LinearRegression   0.03031   0.008943  0.682162
# 6              LinearRegression  0.027464   0.009981   0.66999
# 7              LinearRegression  0.023046   0.005583  0.649247
# 8              LinearRegression  0.018659   0.007018  0.669873
# 9              LinearRegression  0.017137   0.006495  0.669023
# 10  LinearRegression_grid_seach  0.177294   0.012579  0.727858
# 11  LinearRegression_grid_seach  0.192595   0.016104  0.719394
# 12  LinearRegression_grid_seach  0.172961   0.014826  0.690432
# 13  LinearRegression_grid_seach  0.182366   0.019068  0.724373
# 14  LinearRegression_grid_seach  0.197774   0.017066  0.717793
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.006542
# 1                 -75787.787194                    -95217.629397     0.010549
# 2                 -76753.598961                    -96253.253947     0.025124
# 3                 -76837.804811                    -95983.885799     0.007594
# 4                 -76617.245449                    -96182.764729     0.007999
# 5                 -39855.690996                    -54254.958188     0.039253
# 6                 -40272.565467                    -54695.230283     0.037444
# 7                  -42178.05929                    -56955.988706     0.028629
# 8                 -40806.492497                    -55146.318803     0.025677
# 9                 -40788.496497                     -55331.35106     0.023632
# 10                -34669.358538                    -50203.601796     0.189873
# 11                 -35038.50031                    -50435.251621     0.208698
# 12                -37390.557754                     -53507.70879     0.187787
# 13                -35179.835787                    -50389.210245     0.201434
# 14                -35589.707207                    -51092.386155      0.21484

# %%
df_resultados.groupby('model').mean()
# Out:
#                              fit_time score_time   test_r2  \
# model
# DummyRegressor               0.006436   0.005125 -0.000436
# LinearRegression             0.023323   0.007604  0.668059
# LinearRegression_grid_seach  0.184598   0.015928   0.71597
#
#                             test_neg_mean_absolute_error  \
# model
# DummyRegressor                             -76702.495836
# LinearRegression                            -40780.26095
# LinearRegression_grid_seach                -35573.591919
#
#                             test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                 -95975.447913     0.011562
# LinearRegression                               -55276.769408     0.030927
# LinearRegression_grid_seach                    -51125.631722     0.200526

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, eng_formatter=True)
